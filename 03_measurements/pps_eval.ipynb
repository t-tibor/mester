# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
# %matplotlib inline

# %%
fname = "./PPS_log/pps_20.log"

T = np.genfromtxt(fname, delimiter=',',dtype='int64')
ts_l = T[10:,0];
ts_g = T[10:,1];
global_diff = T[10:,2];
tic_sum = T[10:,3];
offset = T[10:,4];
offset_pred = T[10:,5];
p_base = T[10:,6];
p_comp = T[10:,7];

# %%
local_diff = np.diff(ts_l);
global_diff = np.diff(ts_g);

plot(local_diff)
print np.argwhere(local_diff > 2*1e9)
plot(global_diff)
# Out:
# [[ 2247]
#  [ 3569]
#  [ 3745]
#  [29917]
#  [31128]
#  [34602]
#  [36864]]

# %%
plot(ts_l[29900:29930])

show()
print ts_l[3560:3580]

plot(np.diff(ts_l[3560:3580]))
print np.diff(ts_l[3560:3580])*1e-9
# Out:
# [3622402760833 3623402764500 3624402768125 3625402771791 3626121367625
#  3626123166750 3626402775416 3628089191333 3629978219833 3631411885458
#  3655172683791 3656172687416 3657172691041 3658172694666 3659172698333
#  3660172701958 3661172705625 3662172709291 3663172712916 3664172716500]
# [  1.00000367e+00   1.00000362e+00   1.00000367e+00   7.18595834e-01
#    1.79912500e-03   2.79608666e-01   1.68641592e+00   1.88902850e+00
#    1.43366563e+00   2.37607983e+01   1.00000362e+00   1.00000362e+00
#    1.00000362e+00   1.00000367e+00   1.00000362e+00   1.00000367e+00
#    1.00000367e+00   1.00000362e+00   1.00000358e+00]

# %%
# Out:
#   File "<ipython-input-38-416e280e1545>", line 1
#     [1:4]
#       ^
# SyntaxError: invalid syntax
